# %% [markdown]
# # CLAP Few Shot learning using Contrastive Losses
#
#
# This notebook implements a **few-shot audio classification system** for distinguishing between cat and dog sounds using contrastive learning techniques. The system leverages a pre-trained CLAP (Contrastive Language-Audio Pre-training) model as a frozen feature extractor and trains only a small projection head using limited labeled data (5 samples per class by default).
#
#
#
# ### 1. **Contrastive Learning Approaches**
#
# The notebook implements two distinct contrastive learning strategies:
#
# #### **Triplet-Based Contrastive Loss**
# - Uses **anchor-positive-negative triplets** where:
#  - Anchor: reference audio sample
#  - Positive: different sample from same class (cat/dog)
#  - Negative: sample from different class
# - **Margin Ranking Loss**: Encourages `similarity(anchor, positive) > similarity(anchor, negative) + margin`
# - Good for learning discriminative features when you have clear positive/negative pairs
#
# #### **Supervised Contrastive Loss (InfoNCE-style)**
# - Treats all samples from the same class as positives
# - Uses **temperature-scaled cosine similarities** to create probability distributions. This controls softmax sharpness in supervised contrastive loss
# - More robust to batch composition and can leverage multiple positives simultaneously
# - Formula: `-log(sum(exp(sim_positive/τ)) / sum(exp(sim_all/τ)))`
#
# ### 2. **Few-Shot Learning Strategy**
#
# - Only 5 samples per class for training
# - CLAP model parameters are frozen to prevent overfitting
# - Only a small linear layer (512→128 dimensions) is trained
# - Leverages CLAP's pre-trained audio-text representations
#
#
# ### 3. **Class Imbalance Handling**
#
# #### **Oversampling Strategy**
# - Replicates minority class samples up to 3x
# - Maintains class balance without losing data from majority class
#
# #### **Undersampling Alternative**
# - Randomly reduces majority class to match minority class size
# - Faster training but potential information loss
#
# ### 4. **Evaluation Strategy**
#
# #### **Centroid-Based Classification**
# - Computes class centroids from training embeddings
# - Classifies test samples by nearest centroid (cosine similarity)
# - Robust evaluation method for few-shot scenarios
# - No additional classifier training required
#
# ### 5. **Embedding Visualization**
#
# - Visualizes learned embeddings in 2D space
# - Dynamically adjusts perplexity based on sample count
# - Monitors clustering quality across training epochs
# - Helps diagnose if contrastive learning is creating meaningful separations
#
# ### 7. **Technical Implementation Details**
# - **Gradient Clipping**: Prevents exploding gradients (max_norm=1.0)
# - **Similarity Clamping**: Bounds cosine similarities to [-1, 1]
# - **Temperature Scaling**: Controls softmax sharpness in supervised contrastive loss
# - **NaN/Inf Handling**: Robust error checking and fallback mechanisms
# - **Stratified Splitting**: Maintains class proportions across train/val/test
# - **Batch Validation**: Ensures batches contain multiple classes for supervised contrastive loss

# %%
import os
import random
import numpy as np
import torch
import torchaudio
import torch.nn.functional as F
from torch import nn
from torch.utils.data import Dataset, DataLoader
from transformers import ClapProcessor, ClapModel
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from pathlib import Path
import pytorch_lightning as pl

from sklearn.manifold import TSNE
import matplotlib.pyplot as plt


def set_all_seeds(seed=42):
    """Set all random seeds for reproducibility"""
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    pl.seed_everything(seed, workers=True)
    os.environ['PYTHONHASHSEED'] = str(seed)

set_all_seeds(42)

# Configuration
CONFIG_OVER_SAMPLE = {
    "data_dir": "data/cat_dog_audio",
    "balance_method": "oversample",
    "oversample_multiplier": 3,
    "few_shot_per_class": 5,
    "batch_size": 8,
    "epochs": 5,
    "lr": 1e-6,
}

CONFIG_UNDER_SAMPLE = {
    "data_dir": "data/cat_dog_audio",
    "balance_method": "oversample",
    "oversample_multiplier": 3,
    "few_shot_per_class": 5,
    "batch_size": 8,
    "epochs": 5,
    "lr": 1e-6,
}
# Out:
# Seed set to 42

# %%
from src.plots import audio_eda, plot_sample_waveforms
from src.audio import normalize_audio, standardize_duration, augment_audio, preprocess_audio_file
from src.dataset import balance_dataset_explicit
from src.plots import audio_eda, plot_sample_waveforms, plot_tsne_embeddings, plot_dataset_distribution
from src.training import train_contrastive_model, train_supervised_contrastive_model

# %%
def download_kaggle(dest):
    if dest.exists() and list(dest.rglob("*.wav")):
        return
    dest.mkdir(parents=True, exist_ok=True)
    os.system(f"kaggle datasets download -d mmoreaux/audio-cats-and-dogs -p {dest} --unzip")
download_kaggle(Path(CONFIG_OVER_SAMPLE["data_dir"]))

# %%
plot_sample_waveforms("data/cat_dog_audio")

# %%
audio_eda("data/cat_dog_audio")
# Out:
# /Users/mina/workspace/few-shot-audio-classifier/src/plots.py:37: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   duration = librosa.get_duration(filename=str(wav_path))
# === Dataset Summary ===
# Total files: 554
# Cat files: 441 (79.6%)
# Dog files: 113 (20.4%)
#
# Duration stats (seconds):
#   Mean: 6.94
#   Std: 4.58
#   Min: 0.92
#   Max: 17.98
#
# Sample rates found: {16000}

# %% [markdown]
# #### Analysis:
#
# - Audio durations show two peaks : brief clips (~1–2 s) and longer calls (~12 s). Cats are more variable and dogs mostly short.
#
# - Sample rates mix 16 kHz and 44 kHz -> resampling everything to 16 kHz.
#
# - Energy levels are similar across classes but with extreme outliers -> normalizing energy and removing noisy recordings.
#
#
# #### **Standardization Techniques**
# - **Duration Normalization**: Pads short clips to 3 seconds, segments long clips with 50% overlap
# - **Energy Normalization**: RMS normalization with peak limiting backup
# - **Sample Rate Consistency**: Resamples all audio to 48kHz for CLAP compatibility
# - **Silence Trimming**: Removes quiet sections using librosa's trim function

# %%
print('\n ****************************** supervised contrastive with over sampling Dog ****************************** \n')
model, results = train_supervised_contrastive_model(CONFIG_UNDER_SAMPLE)
# Out:
#  ****************************** supervised contrastive with over sampling Dog ******************************
#
# Using device: cpu
# Dataset Distribution Summary:
# ----------------------------------------
# Train (Few-shot): Cat= 5, Dog= 5, Total=10
# Validation     : Cat=151, Dog=37, Total=188
# Test           : Cat=133, Dog=34, Total=167
# Dataset sizes: {'train': 10, 'val': 188, 'test': 167}
# Training supervised contrastive model for 5 epochs...
#   Batch 0: size=8, labels=[0, 0, 0, 1, 1, 0, 1, 0]
#   Batch 1: size=2, labels=[1, 1]
#   Skipping batch 1: size=2, unique_labels=1
#   Processed 1/1 batches successfully
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 2
#       1 print('\n ****************************** supervised contrastive with over sampling Dog ****************************** \n')
# ----> 2 model, results = train_supervised_contrastive_model(CONFIG_UNDER_SAMPLE)
#
# File ~/workspace/few-shot-audio-classifier/src/training.py:324, in train_supervised_contrastive_model(config)
#     321 for epoch in range(1, config["epochs"] + 1):
#     322     # Train using supervised contrastive loss
#     323     train_loss = train_epoch_classification(model, loaders['train'], optimizer, device)
# --> 324     plot_tsne_embeddings(model, loaders['train'], device, epoch)
#     325     # Validate using centroid-based classification
#     326     val_acc, _, _ = evaluate_with_centroids(model, loaders['val'], loaders['train'], device)
#
# File ~/workspace/few-shot-audio-classifier/src/plots.py:224, in plot_tsne_embeddings(model, loader, device, epoch)
#     221 all_labels = []
#     223 with torch.no_grad():
# --> 224     for batch in loader:
#     225         labels = batch['labels'].to(device)
#     226         audio_inputs = {
#     227             k: v.to(device)
#     228             for k, v in batch.items()
#     229             if k in {"input_features", "attention_mask"}
#     230         }
#
# File ~/miniconda3/envs/cat-dog/lib/python3.10/site-packages/torch/utils/data/dataloader.py:733, in _BaseDataLoaderIter.__next__(self)
#     730 if self._sampler_iter is None:
#     731     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     732     self._reset()  # type: ignore[call-arg]
# --> 733 data = self._next_data()
#     734 self._num_yielded += 1
#     735 if (
#     736     self._dataset_kind == _DatasetKind.Iterable
#     737     and self._IterableDataset_len_called is not None
#     738     and self._num_yielded > self._IterableDataset_len_called
#     739 ):
#
# File ~/miniconda3/envs/cat-dog/lib/python3.10/site-packages/torch/utils/data/dataloader.py:789, in _SingleProcessDataLoaderIter._next_data(self)
#     787 def _next_data(self):
#     788     index = self._next_index()  # may raise StopIteration
# --> 789     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     790     if self._pin_memory:
#     791         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~/miniconda3/envs/cat-dog/lib/python3.10/site-packages/torch/utils/data/_utils/fetch.py:52, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      50         data = self.dataset.__getitems__(possibly_batched_index)
#      51     else:
# ---> 52         data = [self.dataset[idx] for idx in possibly_batched_index]
#      53 else:
#      54     data = self.dataset[possibly_batched_index]
#
# File ~/miniconda3/envs/cat-dog/lib/python3.10/site-packages/torch/utils/data/_utils/fetch.py:52, in <listcomp>(.0)
#      50         data = self.dataset.__getitems__(possibly_batched_index)
#      51     else:
# ---> 52         data = [self.dataset[idx] for idx in possibly_batched_index]
#      53 else:
#      54     data = self.dataset[possibly_batched_index]
#
# File ~/workspace/few-shot-audio-classifier/src/dataloader.py:109, in ClassificationDataset.__getitem__(self, idx)
#     107 def __getitem__(self, idx):
#     108     """Return audio inputs and label"""
# --> 109     inputs, label = self._load_audio(idx)
#     110     inputs['labels'] = torch.tensor(label)
#     111     return inputs
#
# File ~/workspace/few-shot-audio-classifier/src/dataloader.py:96, in ClassificationDataset._load_audio(self, idx)
#      94 # Resample to 48kHz if needed
#      95 if sr != 48000:
# ---> 96     wav = torchaudio.functional.resample(wav, sr, 48000)
#      98 # Convert to mono
#      99 wav = wav.mean(0)
#
# File ~/miniconda3/envs/cat-dog/lib/python3.10/site-packages/torchaudio/functional/functional.py:1530, in resample(waveform, orig_freq, new_freq, lowpass_filter_width, rolloff, resampling_method, beta)
#    1517 gcd = math.gcd(int(orig_freq), int(new_freq))
#    1519 kernel, width = _get_sinc_resample_kernel(
#    1520     orig_freq,
#    1521     new_freq,
#    (...)
#    1528     waveform.dtype,
#    1529 )
# -> 1530 resampled = _apply_sinc_resample_kernel(waveform, orig_freq, new_freq, gcd, kernel, width)
#    1531 return resampled
#
# File ~/miniconda3/envs/cat-dog/lib/python3.10/site-packages/torchaudio/functional/functional.py:1467, in _apply_sinc_resample_kernel(waveform, orig_freq, new_freq, gcd, kernel, width)
#    1465 waveform = torch.nn.functional.pad(waveform, (width, width + orig_freq))
#    1466 resampled = torch.nn.functional.conv1d(waveform[:, None], kernel, stride=orig_freq)
# -> 1467 resampled = resampled.transpose(1, 2).reshape(num_wavs, -1)
#    1468 target_length = torch.ceil(torch.as_tensor(new_freq * length / orig_freq)).long()
#    1469 resampled = resampled[..., :target_length]
#
# KeyboardInterrupt:

# %%
# Train using triplet-based contrastive loss
print('\n ****************************** triplet-based contrastive with over sampling Dog ****************************** \n')
model, results = train_contrastive_model(CONFIG_OVER_SAMPLE)
# Out:
#  ****************************** triplet-based contrastive with over sampling Dog ******************************
#
# Using device: cpu
# Found 554 audio files: 441 cats, 113 dogs
# Original distribution: 441 cats, 113 dogs
# Added 226 replicated dog samples
# New distribution: 441 cats, 339 dogs
# Dataset Distribution Summary:
# ----------------------------------------
# Train (Few-shot): Cat= 5, Dog= 5, Total=10
# Validation     : Cat=152, Dog=116, Total=268
# Test           : Cat=132, Dog=102, Total=234
# Dataset sizes: {'train': 10, 'val': 268, 'test': 234}
# Training triplet contrastive model for 5 epochs...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 3
#       1 # Train using triplet-based contrastive loss
#       2 print('\n ****************************** triplet-based contrastive with over sampling Dog ****************************** \n')
# ----> 3 model, results = train_contrastive_model(CONFIG_OVER_SAMPLE)
#
# File ~/workspace/few-shot-audio-classifier/src/training.py:149, in train_contrastive_model(config)
#     146 for epoch in range(1, config["epochs"] + 1):
#     147     # Train using triplet loss
#     148     train_loss, train_triplet_acc = train_epoch(model, loaders['train'], optimizer, device)
# --> 149     plot_tsne_embeddings(model, loaders['train'], device, epoch)
#     151     # Validate using centroid-based classification
#     152     val_acc, _, _ = evaluate_with_centroids(model, loaders['val'], loaders['train'], device)
#
# File ~/workspace/few-shot-audio-classifier/src/plots.py:225, in plot_tsne_embeddings(model, loader, device, epoch)
#     223 with torch.no_grad():
#     224     for batch in loader:
# --> 225         labels = batch['labels'].to(device)
#     226         audio_inputs = {
#     227             k: v.to(device)
#     228             for k, v in batch.items()
#     229             if k in {"input_features", "attention_mask"}
#     230         }
#     231         emb = model.encode_audio(audio_inputs)  # shape: (batch_size, D)
#
# KeyError: 'labels'
